# %% [markdown]
# ## IMPORT LIB.

# %%
import os, io, pandas  as pd

# %%
from google.cloud import vision

# %%
from IPython import display

# %% [markdown]
# ## CREO CREDENCIAL PARA ENTRAR EN CLOUD

# %% [markdown]
# Voy a mi Project
# Activas Api Cloud Vision
# Para que no me obligue a usar mi cuenta, uso una de servicio, via credenciales
# Selecciono cuenta de servicio
# Pongo un nombre descriptivo
# Genero y descargo json para usarlo en mi programa python

# %%
display.Image('Screen Shot 2021-05-12 at 20.14.49.png')

# %% [markdown]
# ## Creo un cliente

# %% [markdown]
# ###  Exporto la clave para no tener que meterla siempre

# %% [markdown]
# ! export GOOGLE_APPLICATION_CREDENTIALS="/home/user/Downloads/service-account-file.json"

# %% [markdown]
# ### Seteo las credenciales segun MacOs / WIN, https://cloud.google.com/docs/authentication/getting-started

# %% [markdown]
# export GOOGLE_APPLICATION_CREDENTIALS="pcd-sol-nguema-edu-marcos-d8f98e783355.json"

# %% [markdown]
# ## Mejor esta forma

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='/Users/christiansucuzhanayarevalo/nominas/pcd-sol-nguema-edu-marcos-d8f98e783355.json'

# %%
client = vision.ImageAnnotatorClient()

# %% [markdown]
# ## Que es : Image Anotator https://googleapis.dev/nodejs/vision/latest/v1.ImageAnnotatorClient.html

# %%
os.listdir()

# %%
pwd

# %%
foto = os.path.abspath('vidalaboral/untitled.txt')

# %%
os.getcwd()

# %%
pwd

# %%
foto

# %%
foto1 = ('Screen Shot 2021-05-12 at 20.14.49.png')

# %%
foto1

# %%
os.getcwd()

# %%
display.Image(foto)

# %%
display.Image(foto1)

# %%
foto1

# %% [markdown]
# ## Creo funcion para detectar y extraer el texto

# %%
### Pero que es io, "como" Pickle, https://docs.python.org/es/3.9/library/io.html

# %%
godoy=open(foto,'rb')#cayo malayo

# %%
contenido_godoy =godoy.read()

# %%
contenido_godoy

# %%
type(read1)

# %%
arribas_spain= open("untitled.txt",'rb')

# %%
arribas_spain_read=arribas_spain.read()

# %%
arribas_spain_read
# Out:
# b'Adi y Arribas, viva Espa\xc3\xb1a'

# %%
arribas_contenido_leible = arribas_spain_read.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-dcd5934bc1cf> in <module>
# ----> 1 arribas_contenido_leible = arribas_spain_read.read()
#
# AttributeError: 'str' object has no attribute 'read'

# %%
godoy_open = open(foto, 'rb')

# %%
def dText(foto):
    with io.open(foto, 'rb') as nomina:
        content = nomina.read()
        
    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    #print(response)
    texts = response.text_annotations
    tabla =pd.DataFrame(columns=['Texto encontrado'])
    
    for text in texts:
        tabla = tabla.append(
            dict(
                Texto_encontrado = text.description
            ),ignore_index=True)
    tabla.to_csv('nominas.csv')
    return tabla

# %% [raw]
# response

# %%
dText(foto)
# Out:
#   Texto encontrado                                   Texto_encontrado
# 0              NaN  godoy\nliquido\n20000\ncategoria\n1\nct\n100\n...
# 1              NaN                                              godoy
# 2              NaN                                            liquido
# 3              NaN                                              20000
# 4              NaN                                          categoria
# 5              NaN                                                  1
# 6              NaN                                                 ct
# 7              NaN                                                100
# 8              NaN                                         antigüedad
# 9              NaN                                                 10

# %%
tabla =pd.DataFrame(columns=['Texto encontrado'])

# %%
tabla

# %%
nominas.csv

# %%
ls

# %%
print(nominas.csv)

# %%
nominas.csv
