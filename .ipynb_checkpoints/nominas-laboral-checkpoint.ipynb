# %%
## IMPORT LIB.

# %%
import os, io, json, pandas  as pd

# %%
from google.cloud import vision

# %%
from IPython import display

# %%
## CREO CREDENCIAL PARA ENTRAR EN CLOUD

# %% [markdown]
# Voy a mi Project
# Activas Api Cloud Vision
# Para que no me obligue a usar mi cuenta, uso una de servicio, via credenciales
# Selecciono cuenta de servicio
# Pongo un nombre descriptivo
# Genero y descargo json para usarlo en mi programa python

# %%
display.Image('JUNIO 2020 copy.png')

# %% [markdown]
# ## Creo un cliente

# %%
client = vision.ImageAnnotatorClient()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-54-cd1d04c9069e> in <module>
# ----> 1 client = vision.ImageAnnotatorClient()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google/cloud/vision_v1/services/image_annotator/client.py in __init__(self, credentials, transport, client_options, client_info)
#     355         else:
#     356             Transport = type(self).get_transport_class(transport)
# --> 357             self._transport = Transport(
#     358                 credentials=credentials,
#     359                 credentials_file=client_options.credentials_file,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google/cloud/vision_v1/services/image_annotator/transports/grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info)
#     151
#     152         # The base transport sets the host, credentials and scopes
# --> 153         super().__init__(
#     154             host=host,
#     155             credentials=credentials,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google/cloud/vision_v1/services/image_annotator/transports/base.py in __init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, **kwargs)
#     100
#     101         elif credentials is None:
# --> 102             credentials, _ = auth.default(
#     103                 scopes=self._scopes, quota_project_id=quota_project_id
#     104             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/google/auth/_default.py in default(scopes, request, quota_project_id)
#     354             return credentials, effective_project_id
#     355
# --> 356     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %% [markdown]
# ## Que es : Image Anotator https://googleapis.dev/nodejs/vision/latest/v1.ImageAnnotatorClient.html

# %%
os.listdir()

# %%
foto = os.path.abspath('JUNIO\ 2020\ copy.png')

# %%
foto

# %%
foto1 = ('JUNIO\ 2020\ copy.png')

# %%
foto1

# %% [markdown]
# ## Creo funcion para detectar y extraer el texto

# %%
### Pero que es io, "como" Pickle, https://docs.python.org/es/3.9/library/io.html

# %%
def dText(foto):
    with io.open(foto, 'rb') as nomina:
        content = nomina.read()
        
    img = vision.Image(content=content)
    responde = client
